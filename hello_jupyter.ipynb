# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv")

# %%
data.iloc[100:110, 2:5]
# Out:
#      displacement  horsepower  weight
# 100         250.0        88.0    3021
# 101         198.0        95.0    2904
# 102          97.0        46.0    1950
# 103         400.0       150.0    4997
# 104         400.0       167.0    4906
# 105         360.0       170.0    4654
# 106         350.0       180.0    4499
# 107         232.0       100.0    2789
# 108          97.0        88.0    2279
# 109         140.0        72.0    2401

# %%
subdata = data.iloc[100:110, 2:5]

# %%
data.iloc[2]
# Out:
# mpg                           18.0
# cylinders                        8
# displacement                 318.0
# horsepower                   150.0
# weight                        3436
# acceleration                  11.0
# model_year                      70
# origin                         usa
# name            plymouth satellite
# Name: 2, dtype: object

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data.iloc[2,2]
#idx = 2,2
#data.iloc[idx]
# Out:
# 318.0

# %%
coo = (2,"displacement")
data.loc[coo]
# Out:
# 318.0

# %%
data["mpg"] # better code
# data["mpg"] = data.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
data["column"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Mr.Grumpy\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Mr.Grumpy\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Mr.Grumpy\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
2 * data["mpg"] # 18 * 2
# Out:
# 0      36.0
# 1      30.0
# 2      36.0
# 3      32.0
# 4      34.0
#        ...
# 393    54.0
# 394    88.0
# 395    64.0
# 396    56.0
# 397    62.0
# Name: mpg, Length: 398, dtype: float64

# %%
list(data["mpg"])
# Out:
# [18.0,
#  15.0,
#  18.0,
#  16.0,
#  17.0,
#  15.0,
#  14.0,
#  14.0,
#  14.0,
#  15.0,
#  15.0,
#  14.0,
#  15.0,
#  14.0,
#  24.0,
#  22.0,
#  18.0,
#  21.0,
#  27.0,
#  26.0,
#  25.0,
#  24.0,
#  25.0,
#  26.0,
#  21.0,
#  10.0,
#  10.0,
#  11.0,
#  9.0,
#  27.0,
#  28.0,
#  25.0,
#  25.0,
#  19.0,
#  16.0,
#  17.0,
#  19.0,
#  18.0,
#  14.0,
#  14.0,
#  14.0,
#  14.0,
#  12.0,
#  13.0,
#  13.0,
#  18.0,
#  22.0,
#  19.0,
#  18.0,
#  23.0,
#  28.0,
#  30.0,
#  30.0,
#  31.0,
#  35.0,
#  27.0,
#  26.0,
#  24.0,
#  25.0,
#  23.0,
#  20.0,
#  21.0,
#  13.0,
#  14.0,
#  15.0,
#  14.0,
#  17.0,
#  11.0,
#  13.0,
#  12.0,
#  13.0,
#  19.0,
#  15.0,
#  13.0,
#  13.0,
#  14.0,
#  18.0,
#  22.0,
#  21.0,
#  26.0,
#  22.0,
#  28.0,
#  23.0,
#  28.0,
#  27.0,
#  13.0,
#  14.0,
#  13.0,
#  14.0,
#  15.0,
#  12.0,
#  13.0,
#  13.0,
#  14.0,
#  13.0,
#  12.0,
#  13.0,
#  18.0,
#  16.0,
#  18.0,
#  18.0,
#  23.0,
#  26.0,
#  11.0,
#  12.0,
#  13.0,
#  12.0,
#  18.0,
#  20.0,
#  21.0,
#  22.0,
# ...

# %%
data["cylinders"] + data["mpg"] # 8 + 18 = 26
# Out:
# 0      26.0
# 1      23.0
# 2      26.0
# 3      24.0
# 4      25.0
#        ...
# 393    31.0
# 394    48.0
# 395    36.0
# 396    32.0
# 397    35.0
# Length: 398, dtype: float64

# %%
data["mpg"] < 20 # outcome is boolean (mass)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: mpg, Length: 398, dtype: bool

# %%
mask= data["mpg"] < 20 # input in index it will show the number
data[mask]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 290  15.5          8         351.0       142.0    4054          14.3
# 291  19.2          8         267.0       125.0    3605          15.0
# 292  18.5          8         360.0       150.0    3940          13.0
# 316  19.1          6         225.0        90.0    3381          18.7
# 366  17.6          6         225.0        85.0    3465          16.6
#
#      model_year origin                                  name
# 0            70    usa             chevrolet chevelle malibu
# ...

# %%
data[data.mpg <20] # == mask= data["mpg"] < 20 # input in index it will show the number
#data[mask]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 290  15.5          8         351.0       142.0    4054          14.3
# 291  19.2          8         267.0       125.0    3605          15.0
# 292  18.5          8         360.0       150.0    3940          13.0
# 316  19.1          6         225.0        90.0    3381          18.7
# 366  17.6          6         225.0        85.0    3465          16.6
#
#      model_year origin                                  name
# 0            70    usa             chevrolet chevelle malibu
# ...

# %%
mpg_mask = data["mpg"] <20
year_mask = data["model_year"]>= 80
final_mask = mpg_mask and year_mask
data[final_mask]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 mpg_mask = data["mpg"] <20
#       2 year_mask = data["model_year"]>= 80
# ----> 3 final_mask = mpg_mask and year_mask
#       4 data[final_mask]
#
# File c:\Users\Mr.Grumpy\miniconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data.query("mpg < 20 & model_year >= 80") #works good job
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 316  19.1          6         225.0        90.0    3381          18.7
# 366  17.6          6         225.0        85.0    3465          16.6
#
#      model_year origin                    name
# 316          80    usa             dodge aspen
# 366          81    usa  chrysler lebaron salon

# %%
x = 5
print (f"Twice {x}is {2*x}")
# Out:
# Twice 5is 10

# %% [markdown]
# <h1>Hello </h1>
# # Hello!
# <p> Let try this out</p>
# * Note*
# Formatted math $E = mc^2$
